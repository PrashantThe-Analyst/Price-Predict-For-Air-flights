# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\HP\Downloads\AirFlights_Data.xlsx")

# %%
df.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df[df["Route"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df[(df["Source"] == "Delhi") & (df["Destination"] == "Cochin")]
# Out:
#                  Airline Date_of_Journey Source Destination  \
# 2            Jet Airways       9/06/2019  Delhi      Cochin
# 9      Multiple carriers      27/05/2019  Delhi      Cochin
# 10             Air India       1/06/2019  Delhi      Cochin
# 15             Air India       3/03/2019  Delhi      Cochin
# 16              SpiceJet      15/04/2019  Delhi      Cochin
# ...                  ...             ...    ...         ...
# 10669          Air India      15/06/2019  Delhi      Cochin
# 10672        Jet Airways      27/06/2019  Delhi      Cochin
# 10673        Jet Airways      27/05/2019  Delhi      Cochin
# 10676  Multiple carriers       1/05/2019  Delhi      Cochin
# 10682          Air India       9/05/2019  Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 9            DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# ...

# %%
fill=df["Total_Stops"].mode()[0]

# %%
df["Total_Stops"].fillna(fill,inplace=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.drop(["Route","Additional_Info"],axis=1,inplace=True)

# %%
# Extract month and day 
df["month_of_J"]=pd.to_datetime(df["Date_of_Journey"]).dt.month
df["day_of_J"]=pd.to_datetime(df["Date_of_Journey"]).dt.day

# %%
# Extract hours and minutes 
df["dep_hour"]=pd.to_datetime(df["Dep_Time"]).dt.hour
df["dep_minute"]=pd.to_datetime(df["Dep_Time"]).dt.minute

# %%
# Extract hours and minutes 
df["Arrival_hour"]=pd.to_datetime(df["Arrival_Time"]).dt.hour
df["Arrival_minute"]=pd.to_datetime(df["Arrival_Time"]).dt.minute

# %%
# how to extract hour and minute in duration column

# %%
df['Duration_Hour'] = df['Duration'].str.extract(r'(\d+)h')
df['Duration_Minute'] = df['Duration'].str.extract(r'(\d+)m')

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
#
#   Duration Total_Stops  Price  month_of_J  day_of_J  dep_hour  dep_minute  \
# 0   2h 50m    non-stop   3897           3        24        22          20
# 1   7h 25m     2 stops   7662           5         1         5          50
# 2      19h     2 stops  13882           6         9         9          25
#
#    Arrival_hour  Arrival_minute Duration_Hour Duration_Minute
# 0             1              10             2              50
# 1            13              15             7              25
# 2             4              25            19             NaN

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Price              0
# month_of_J         0
# day_of_J           0
# dep_hour           0
# dep_minute         0
# Arrival_hour       0
# Arrival_minute     0
# Duration_Hour      0
# Duration_Minute    0
# dtype: int64

# %%
df[df["Duration_Minute"].isnull()]
# Out:
#                  Airline Date_of_Journey    Source Destination Dep_Time  \
# 2            Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 18             Air India      12/06/2019     Delhi      Cochin    20:15
# 33           Jet Airways      15/06/2019     Delhi      Cochin    14:35
# 44     Multiple carriers      21/03/2019     Delhi      Cochin    09:00
# 53                IndiGo      18/06/2019  Banglore       Delhi    21:15
# ...                  ...             ...       ...         ...      ...
# 10591        Jet Airways      12/06/2019     Delhi      Cochin    20:00
# 10638        Jet Airways      21/03/2019  Banglore   New Delhi    21:25
# 10639          Air India       3/06/2019     Delhi      Cochin    05:15
# 10673        Jet Airways      27/05/2019     Delhi      Cochin    13:25
# 10680        Jet Airways      27/04/2019  Banglore       Delhi    08:20
#
#        Arrival_Time Duration Total_Stops  Price  month_of_J  day_of_J  \
# ...

# %%
df["Duration_Minute"].fillna(0,inplace=True)

# %%
df[df["Duration_Hour"].isnull()]
# Out:
#         Airline Date_of_Journey  Source Destination Dep_Time Arrival_Time  \
# 6474  Air India       6/03/2019  Mumbai   Hyderabad    16:50        16:55
#
#      Duration Total_Stops  Price  month_of_J  day_of_J  dep_hour  dep_minute  \
# 6474       5m     2 stops  17327           3         6        16          50
#
#       Arrival_hour  Arrival_minute Duration_Hour Duration_Minute
# 6474            16              55           NaN               5

# %%
df["Duration_Hour"].fillna(0,inplace=True)

# %%
df[df["Duration_Hour"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Dep_Time, Arrival_Time, Duration, Total_Stops, Price, month_of_J, day_of_J, dep_hour, dep_minute, Arrival_hour, Arrival_minute, Duration_Hour, Duration_Minute]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   month_of_J       10683 non-null  int32
#  10  day_of_J         10683 non-null  int32
#  11  dep_hour         10683 non-null  int32
#  12  dep_minute       10683 non-null  int32
#  13  Arrival_hour     10683 non-null  int32
#  14  Arrival_minute   10683 non-null  int32
#  15  Duration_Hour    10683 non-null  object
#  16  Duration_Minute  10683 non-null  object
# ...

# %%
df["Duration_Hour"]=df["Duration_Hour"].astype(int)

# %%
df["Duration_Minute"]=df["Duration_Minute"].astype(int)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Price              0
# month_of_J         0
# day_of_J           0
# dep_hour           0
# dep_minute         0
# Arrival_hour       0
# Arrival_minute     0
# Duration_Hour      0
# Duration_Minute    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   month_of_J       10683 non-null  int32
#  10  day_of_J         10683 non-null  int32
#  11  dep_hour         10683 non-null  int32
#  12  dep_minute       10683 non-null  int32
#  13  Arrival_hour     10683 non-null  int32
#  14  Arrival_minute   10683 non-null  int32
#  15  Duration_Hour    10683 non-null  int32
#  16  Duration_Minute  10683 non-null  int32
# ...

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
#
#   Duration Total_Stops  Price  month_of_J  day_of_J  dep_hour  dep_minute  \
# 0   2h 50m    non-stop   3897           3        24        22          20
# 1   7h 25m     2 stops   7662           5         1         5          50
# 2      19h     2 stops  13882           6         9         9          25
#
#    Arrival_hour  Arrival_minute  Duration_Hour  Duration_Minute
# 0             1              10              2               50
# 1            13              15              7               25
# 2             4              25             19                0

# %%
df1=df.drop(["Date_of_Journey","Dep_Time","Arrival_Time","Duration"],axis=1)

# %%
df1
# Out:
#            Airline    Source Destination Total_Stops  Price  month_of_J  \
# 0           IndiGo  Banglore   New Delhi    non-stop   3897           3
# 1        Air India   Kolkata    Banglore     2 stops   7662           5
# 2      Jet Airways     Delhi      Cochin     2 stops  13882           6
# 3           IndiGo   Kolkata    Banglore      1 stop   6218           5
# 4           IndiGo  Banglore   New Delhi      1 stop  13302           3
# ...            ...       ...         ...         ...    ...         ...
# 10678     Air Asia   Kolkata    Banglore    non-stop   4107           4
# 10679    Air India   Kolkata    Banglore    non-stop   4145           4
# 10680  Jet Airways  Banglore       Delhi    non-stop   7229           4
# 10681      Vistara  Banglore   New Delhi    non-stop  12648           3
# 10682    Air India     Delhi      Cochin     2 stops  11753           5
#
#        day_of_J  dep_hour  dep_minute  Arrival_hour  Arrival_minute  \
# ...

# %%
df1["Total_Stops"].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
df1["Total_Stops"].replace("non-stop","0 stop",inplace=True)

# %%
df1["Total_Stops"]=df1["Total_Stops"].replace("[A-z]","",regex=True).astype(int)

# %%
df1[["Airline","Source","Destination"]]
# Out:
#            Airline    Source Destination
# 0           IndiGo  Banglore   New Delhi
# 1        Air India   Kolkata    Banglore
# 2      Jet Airways     Delhi      Cochin
# 3           IndiGo   Kolkata    Banglore
# 4           IndiGo  Banglore   New Delhi
# ...            ...       ...         ...
# 10678     Air Asia   Kolkata    Banglore
# 10679    Air India   Kolkata    Banglore
# 10680  Jet Airways  Banglore       Delhi
# 10681      Vistara  Banglore   New Delhi
# 10682    Air India     Delhi      Cochin
#
# [10683 rows x 3 columns]

# %%
df1["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
df1[["Airline","Source","Destination"]]=df1[["Airline","Source","Destination"]].apply(enc.fit_transform)

# %%
df1["Airline"].unique()
# Out:
# array([ 3,  1,  4,  8,  6,  2, 10,  0, 11,  5,  7,  9])

# %%
df1.head(3)
# Out:
#    Airline  Source  Destination  Total_Stops  Price  month_of_J  day_of_J  \
# 0        3       0            5            0   3897           3        24
# 1        1       3            0            2   7662           5         1
# 2        4       2            1            2  13882           6         9
#
#    dep_hour  dep_minute  Arrival_hour  Arrival_minute  Duration_Hour  \
# 0        22          20             1              10              2
# 1         5          50            13              15              7
# 2         9          25             4              25             19
#
#    Duration_Minute
# 0               50
# 1               25
# 2                0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import seaborn as sns

# %%
x=df1.drop("Price",axis=1)

# %%
y=df1["Price"]

# %%
df1.shape
# Out:
# (10683, 13)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.1,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre=model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pre)
r2 = r2_score(y_test, y_pre)
print(mse)
print(r2)
# Out:
# 12386549.51710007
# 0.42781788425245426

# %%
# predict new price base on new data

# %%
newdata=[[3,0,5,0,3,24,22,20,1,10,2,50]]

# %%
model.predict(newdata)
# Out:
# array([6434.37955169])
